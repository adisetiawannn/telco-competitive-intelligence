# %% [raw]
# # ==============================================
# # database backup command
# # ==============================================
# cp data/articles.db data/articles_backup_$(date +%Y%m%d).db
